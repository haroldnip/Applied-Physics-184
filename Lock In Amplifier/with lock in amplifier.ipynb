# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data from the CSV file
file_pathl0t = 'l0t.csv'  # Replace with your file's path
datal0t = pd.read_csv(file_pathl0t)

file_pathl0w = 'l0w.csv'  # Replace with your file's path
datal0w = pd.read_csv(file_pathl0w)

file_pathl10w = 'l10w.csv'  # Replace with your file's path
datal10w = pd.read_csv(file_pathl10w)

file_pathl1w = 'l1w.csv'  # Replace with your file's path
datal1w = pd.read_csv(file_pathl1w)

file_pathl2w = 'l2w.csv'  # Replace with your file's path
datal2w = pd.read_csv(file_pathl2w)

file_pathl4w = 'l4w.csv'  # Replace with your file's path
datal4w = pd.read_csv(file_pathl4w)

file_pathl6w = 'l6w.csv'  # Replace with your file's path
datal6w = pd.read_csv(file_pathl6w)

file_pathl8w = 'l8w.csv'  # Replace with your file's path
datal8w = pd.read_csv(file_pathl8w)


# Inspect the first few rows to verify the structure
#print(data.head())

# Extract Time and Voltage columns
timel0t = datal0t['Time']  # Replace with the actual column name for time
voltagel0t = datal0t['Volt']  # Replace with the actual column name for voltage

timel0w = datal0w['Time']  # Replace with the actual column name for time
voltagel0w = datal0w['Volt']  # Replace with the actual column name for voltage

timel10w = datal10w['Time']  # Replace with the actual column name for time
voltagel10w = datal10w['Volt']  # Replace with the actual column name for voltage

timel1w = datal1w['Time']  # Replace with the actual column name for time
voltagel1w = datal1w['Volt']  # Replace with the actual column name for voltage

timel2w = datal2w['Time']  # Replace with the actual column name for time
voltagel2w = datal2w['Volt']  # Replace with the actual column name for voltage

timel4w = datal4w['Time']  # Replace with the actual column name for time
voltagel4w = datal4w['Volt']  # Replace with the actual column name for voltage

timel6w = datal6w['Time']  # Replace with the actual column name for time
voltagel6w = datal6w['Volt']  # Replace with the actual column name for voltage

timel8w = datal8w['Time']  # Replace with the actual column name for time
voltagel8w = datal8w['Volt']  # Replace with the actual column name for voltage

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(timel0t, voltagel0t, marker='o', linestyle='-', color='blue', label='LED off')
plt.plot(timel1w, voltagel1w, marker='o', linestyle='-', color='purple', label='1 inch')
plt.plot(timel2w, voltagel2w, marker='o', linestyle='-', color='yellow', label='2 inches')
plt.plot(timel4w, voltagel4w, marker='o', linestyle='-', color='orange', label='4 inches')
plt.plot(timel6w, voltagel6w, marker='o', linestyle='-', color='black', label='6 inches')
plt.plot(timel8w, voltagel8w, marker='o', linestyle='-', color='gray', label='8 inches')
plt.plot(timel10w, voltagel10w, marker='o', linestyle='-', color='green', label='10 inches')
#plt.plot(timel0w, voltagel0w, marker='o', linestyle='-', color='red', label='LED off')


# Customize the plot
#plt.title('Voltage vs Time')
plt.xlabel('Time [s]')
plt.xlim(-0.0000001, 0.0000001)
plt.ylabel('Voltage [V]')
plt.ylim(-0.3,2)
plt.grid(True)
plt.legend()
plt.savefig("with lock in")
# Show the plot
plt.show()

# %% [markdown]
# #####
